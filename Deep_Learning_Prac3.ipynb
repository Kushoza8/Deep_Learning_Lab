# %% [markdown]
# # PRACTICAL-2

# %% [raw]
# prepare a titanic and heart disease dataset for training with Machine Learning Algo by applying
# suitable data preprocessing techniques
#
# 1.perform basic EDA using function like head,tail,describe,shape,etc.
# 2.idenitify and handle missing values
# 3.check for duplicate and handle it
# 4.apply data encoding technique on suitable attributes
# 5.apply univariant,bivariant and multivariant data analysis
# 6.split the dataset in ratio 80:20

# %%
1+1
# Out:
# 2

# %%
import numpy as np
import pandas as pd

# %%
df=pd.read_csv('Titanic-Dataset.csv')

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df.shape
# Out:
# (891, 12)

# %%
df.shape[1]
# Out:
# 12

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
df.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
1+1
# Out:
# 2

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
del df['Parch']

# %%
del df['Ticket']

# %%
del df['Embarked']

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
print(np.mean(df.Age))
# Out:
# 29.69911764705882

# %%
df.Age.fillna(np.mean(df.Age),inplace=True)

# %%
df.Age.isnull().sum()
# Out:
# 0

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex        Age  \
# 0                              Braund, Mr. Owen Harris    male  22.000000
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.000000
# 2                               Heikkinen, Miss. Laina  female  26.000000
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.000000
# 4                             Allen, Mr. William Henry    male  35.000000
# ..                                                 ...     ...        ...
# ...

# %%
df.Sex.replace('male',1,inplace=True)
df.Sex.replace('female',0,inplace=True)

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name  Sex        Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    1  22.000000      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...    0  38.000000      1
# 2                               Heikkinen, Miss. Laina    0  26.000000      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)    0  35.000000      1
# 4                             Allen, Mr. William Henry    1  35.000000      0
# ...

# %%
del df['Cabin']

# %%
del df['SibSp']

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name  Sex        Age  \
# 0                              Braund, Mr. Owen Harris    1  22.000000
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...    0  38.000000
# 2                               Heikkinen, Miss. Laina    0  26.000000
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)    0  35.000000
# 4                             Allen, Mr. William Henry    1  35.000000
# ..                                                 ...  ...        ...
# ...

# %%
df.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'Fare'], dtype='object')

# %%
df.columns[2]
# Out:
# 'Pclass'

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name  Sex        Age  \
# 0                              Braund, Mr. Owen Harris    1  22.000000
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...    0  38.000000
# 2                               Heikkinen, Miss. Laina    0  26.000000
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)    0  35.000000
# 4                             Allen, Mr. William Henry    1  35.000000
# ..                                                 ...  ...        ...
# ...

# %%
target=df.Survived

# %%
target
# Out:
# 0      0
# 1      1
# 2      1
# 3      1
# 4      0
#       ..
# 886    0
# 887    1
# 888    0
# 889    1
# 890    0
# Name: Survived, Length: 891, dtype: int64

# %%
del df['Survived']

# %%
del df['PassengerId']

# %%
df
# Out:
#      Pclass                                               Name  Sex  \
# 0         3                            Braund, Mr. Owen Harris    1
# 1         1  Cumings, Mrs. John Bradley (Florence Briggs Th...    0
# 2         3                             Heikkinen, Miss. Laina    0
# 3         1       Futrelle, Mrs. Jacques Heath (Lily May Peel)    0
# 4         3                           Allen, Mr. William Henry    1
# ..      ...                                                ...  ...
# 886       2                              Montvila, Rev. Juozas    1
# 887       1                       Graham, Miss. Margaret Edith    0
# 888       3           Johnston, Miss. Catherine Helen "Carrie"    0
# 889       1                              Behr, Mr. Karl Howell    1
# 890       3                                Dooley, Mr. Patrick    1
#
#            Age     Fare
# 0    22.000000   7.2500
# 1    38.000000  71.2833
# 2    26.000000   7.9250
# 3    35.000000  53.1000
# ...

# %%
X=df

# %%
X
# Out:
#      Pclass                                               Name  Sex  \
# 0         3                            Braund, Mr. Owen Harris    1
# 1         1  Cumings, Mrs. John Bradley (Florence Briggs Th...    0
# 2         3                             Heikkinen, Miss. Laina    0
# 3         1       Futrelle, Mrs. Jacques Heath (Lily May Peel)    0
# 4         3                           Allen, Mr. William Henry    1
# ..      ...                                                ...  ...
# 886       2                              Montvila, Rev. Juozas    1
# 887       1                       Graham, Miss. Margaret Edith    0
# 888       3           Johnston, Miss. Catherine Helen "Carrie"    0
# 889       1                              Behr, Mr. Karl Howell    1
# 890       3                                Dooley, Mr. Patrick    1
#
#            Age     Fare
# 0    22.000000   7.2500
# 1    38.000000  71.2833
# 2    26.000000   7.9250
# 3    35.000000  53.1000
# ...

# %%
y=target
y
# Out:
# 0      0
# 1      1
# 2      1
# 3      1
# 4      0
#       ..
# 886    0
# 887    1
# 888    0
# 889    1
# 890    0
# Name: Survived, Length: 891, dtype: int64

# %%
#dependent is o/p and independent is i/p

# %%
del X['Name']

# %%
del X['Fare']

# %%
X
# Out:
#      Pclass  Sex        Age
# 0         3    1  22.000000
# 1         1    0  38.000000
# 2         3    0  26.000000
# 3         1    0  35.000000
# 4         3    1  35.000000
# ..      ...  ...        ...
# 886       2    1  27.000000
# 887       1    0  19.000000
# 888       3    0  29.699118
# 889       1    1  26.000000
# 890       3    1  32.000000
#
# [891 rows x 3 columns]

# %%
y
# Out:
# 0      0
# 1      1
# 2      1
# 3      1
# 4      0
#       ..
# 886    0
# 887    1
# 888    0
# 889    1
# 890    0
# Name: Survived, Length: 891, dtype: int64

# %%
len(X_train)
# Out:
# 623

# %%
len(X_test)
# Out:
# 268

# %%
class Perceptron:
    def __init__(self,learning_rate,epochs):
        self.weights=None
        self.bias=None
        self.learning_rate=learning_rate
        self.epochs=epochs
       
    def activation(self,z):
        return np.heaviside(z,0)
   
    def fit(self,X,y):
        n_samples,n_features=X.shape
        self.weights=np.zeros(n_features)
        self.bias=0
       
        for epoch in range(self.epochs):
            for i in range(n_samples):
                z=np.dot(X.iloc[i],self.weights)+self.bias
                y_pred=self.activation(z)
               
                self.weights+=self.learning_rate*(y.iloc[i]-y_pred)*X.iloc[i]
                self.bias+=self.learning_rate*(y.iloc[i]-y_pred)
               
    def predict(self,X):
        z=np.dot(X,self.weights)+self.bias
        return self.activation(z)

# %%
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix,accuracy_score,precision_score,recall_score,f1_score

# %%
X_train,X_test,y_train,y_test= train_test_split (X,y,test_size=0.3)

# %%
perceptron=Perceptron(0.01,10)

# %%
perceptron.fit(X_train,y_train)

# %%
pred=perceptron.predict(X_test)

# %%
from sklearn.metrics import classification_report

# %%
report=classification_report(y_test,pred)

# %%
print(report)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.84      0.70      0.77       162
#            1       0.64      0.79      0.71       106
#
#     accuracy                           0.74       268
#    macro avg       0.74      0.75      0.74       268
# weighted avg       0.76      0.74      0.74       268
